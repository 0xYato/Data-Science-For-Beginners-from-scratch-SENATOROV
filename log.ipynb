# %%
"""Add log.ipynb."""

# %% [markdown]
# # 03/08
#
# # 1. Сделал форк и скачал репозиторий на свой пк
# # 2. Освежил память основных команд git с помощью файла docs\git\git_command.ipynb
# # 3. Узнал что существует вообще pre-commit(перед этим в командах просто вообще не работал)
# # 4. Познакомился с линтерами(узнал как где искать ошибки и их решения)
# # 5. Познакомился с регламентом отправления домашних заданий
# # 6. Узнал что делать при работе в одном файле и возникновении конфликтов
